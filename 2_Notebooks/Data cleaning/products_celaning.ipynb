# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\shahi\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\shahi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('products.csv')
df.head()
# Out:
#   product_id    product_name     category unit_price  margin_pct
# 0      P0001   Sports Item 1  Electronics    6017.98        0.34
# 1      P0002   Beauty Item 2      Apparel   13910.88        0.14
# 2      P0003  Apparel Item 3  electronics   10949.99        0.15
# 3      P0004   Beauty Item 4      Apparel  ₹4,999.13        0.07
# 4      P0005   Beauty Item 5       Beauty    8621.09        0.33

# %%
df.shape
# Out:
# (41, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    41 non-null     str
#  1   product_name  41 non-null     str
#  2   category      37 non-null     str
#  3   unit_price    41 non-null     str
#  4   margin_pct    41 non-null     float64
# dtypes: float64(1), str(4)
# memory usage: 1.7 KB

# %%
df.dtypes
# Out:
# product_id          str
# product_name        str
# category            str
# unit_price          str
# margin_pct      float64
# dtype: object

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'unit_price', 'margin_pct'], dtype='str')

# %% [markdown]
# #### Check Duplicates

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### Check Null values

# %%
nv = df.isnull().sum()
nv_df = nv[nv>0]
nv_df
# Out:
# category    4
# dtype: int64

# %% [markdown]
# #### EDA

# %%
df['product_name'] = df['product_name'].str[:-2]

# %%
df['product_name'] = df['product_name'].str.strip()

# %%
df['product_name'].value_counts()
# Out:
# product_name
# Sports Item            10
# Apparel Item            8
# Beauty Item             7
# Grocery Item            7
# Home & Kitchen Item     5
# Electronics Item        3
# Name: count, dtype: int64

# %%
df['category'] = df['category'].str.lower().str.strip()

# %%
df['category'].value_counts()
# Out:
# category
# home & kitchen    10
# sports             9
# grocery            6
# electronics        4
# apparel            4
# beauty             3
# Name: count, dtype: int64

# %%
df['category'] = df['category'].fillna(df['category'].mode()[0])

# %%
df['unit_price'] = df['unit_price'].str.replace(",","")

# %%
df['unit_price'] = df['unit_price'].str.replace("₹","")

# %%
df['unit_price'] = df['unit_price'].str.replace("-","")

# %%
df.drop(df[df['unit_price'] == '0.0'].index, inplace=True)

# %%
df['unit_price'] = pd.to_numeric(df['unit_price'])

# %%
df.dtypes
# Out:
# product_id          str
# product_name        str
# category            str
# unit_price      float64
# margin_pct      float64
# dtype: object

# %%
df.to_csv('products_cleaned.csv',index = False)
